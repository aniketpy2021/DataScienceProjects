# %% [markdown]
# ### Simple Linear Regression

# %% [raw]
# Proble Statement: On the basis of Wine Contents we want to predict wine quality
# Data Set: Wine Quality
#
# Target Variable: Quality
# Independent Variable: Densicy, PH, Alcohol

# %%
# %pip install numpy pandas matplotlib seaborn
# %pip install -U scikit-learn
# Out:
# ...
#   Using cached numpy-2.2.4-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pandas-2.2.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached matplotlib-3.10.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached contourpy-1.3.1-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.56.0-cp313-cp313-win_amd64.whl.metadata (103 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached pillow-11.1.0-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached numpy-2.2.4-cp313-cp313-win_amd64.whl (12.6 MB)
# Using cached pandas-2.2.3-cp313-cp313-win_amd64.whl (11.5 MB)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Wine Quality Dataset.csv')

# %%
df.head()
# Out:
#    Id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   0            7.4              0.70         0.00             1.9
# 1   1            7.8              0.88         0.00             2.6
# 2   2            7.8              0.76         0.04             2.3
# 3   3           11.2              0.28         0.56             1.9
# 4   4            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# 2       0.65      9.8        5
# ...

# %%
df.columns
# Out:
# Index(['Id', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
df.shape
# Out:
# (200, 4)

# %%
# X = df[['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol']]  
# X = df[['density', 'pH', 'alcohol']]  
# y = df['quality']  
# x1 = df['fixed acidity']
# x2 = df['volatile acidity']
# x3 = df['citric acid']
# x4 = df['residual sugar']
# x5 = df['chlorides']
# x6 = df['free sulfur dioxide']
# x7 = df['total sulfur dioxide']
# x8 = df['density']
# x9 = df['pH']
# x10 = df['sulphates']
# x11 = df['alcohol']

X = df[['density', 'pH', 'alcohol']]  
y = df['quality']  
x1 = df['density']
x2 = df['pH']
x3 = df['alcohol']

# %%
df.corr()
# Out:
#                             Id  fixed acidity  volatile acidity  citric acid  \
# Id                    1.000000      -0.275826         -0.007892    -0.139011
# fixed acidity        -0.275826       1.000000         -0.250728     0.673157
# volatile acidity     -0.007892      -0.250728          1.000000    -0.544187
# citric acid          -0.139011       0.673157         -0.544187     1.000000
# residual sugar       -0.046344       0.171831         -0.005751     0.175815
# chlorides            -0.088099       0.107889          0.056336     0.245312
# free sulfur dioxide   0.095268      -0.164831         -0.001962    -0.057589
# total sulfur dioxide -0.107389      -0.110628          0.077748     0.036871
# density              -0.363926       0.681501          0.016512     0.375243
# pH                    0.132904      -0.685163          0.221492    -0.546339
# sulphates            -0.103954       0.174592         -0.276079     0.331232
# ...

# %% [markdown]
# plt.scatter(x,y)
# plt.xlabel('TV advertisement Price')
# plt.ylabel('Sales based on Advertising')
# plt.title('Scatter plot between Sales and TV advertise')

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#training and testing process
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state=0)

# %%
len(x_train)
# Out:
# 800

# %%
len(y_test)
# Out:
# 343

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
#x_train = np.array(x_train).reshape(-1,1)
#y_train = np.array(y_train).reshape(-1,1)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_  #beta 1 , beta 2 beta3
# Out:
# array([ 1.34180375, -0.84694353,  0.37785946])

# %%
model.intercept_  #beta0
# Out:
# np.float64(3.187338611868149)

# %%
Sales = 3.187338611868149 + 1.34180375 * x1 + -0.84694353 * x2 + 0.37785946 * x3

# %% [raw]
# line = model.intercept_ + model.coef_* x
# plt.scatter(df['alcohol'], df['quality'], color = 'r')
# plt.plot(x,line)
# plt.xlabel('alchohol content')
# plt.ylabel('wine quality')
# plt.title('Scatter plot between Alcohol Content and Wine Quality')

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([5.46009244, 5.85699106, 5.50685775, 5.63635825, 5.29325226,
#        5.56709995, 5.21072267, 5.70424697, 5.95969773, 5.59776817,
#        5.3339723 , 5.98570985, 5.58643525, 5.27024133, 6.11855954,
#        5.31921521, 5.66965362, 5.09788368, 5.29712116, 5.43133854,
#        5.56701143, 5.40429418, 5.26878322, 5.18457191, 5.18979063,
#        5.18121124, 5.10621893, 5.70424697, 6.02668392, 5.17107608,
#        5.30447239, 5.58724127, 5.78861389, 5.66351095, 5.44556882,
#        5.7681345 , 5.87406411, 5.40508135, 5.24939425, 5.93054223,
#        5.44922564, 6.25489702, 5.65103488, 6.03592265, 5.20122005,
#        5.42215534, 5.26567023, 5.85956737, 6.4566258 , 6.20621743,
#        5.52727987, 6.25453397, 5.59649697, 6.32177677, 5.23541536,
#        5.33368606, 5.46714848, 5.43102642, 5.32577122, 6.0095572 ,
#        5.76509847, 5.12032304, 5.25093638, 5.55914044, 5.5003419 ,
#        5.36632038, 6.35154409, 5.45956022, 5.58005011, 5.6790176 ,
# ...

# %%
df = pd.DataFrame({'Actual':y_test, 'predicted':y_pred})
df
# Out:
#      Actual  predicted
# 946       5   5.460092
# 142       4   5.856991
# 934       6   5.506858
# 625       6   5.636358
# 124       5   5.293252
# ..      ...        ...
# 230       6   5.331121
# 402       5   5.394448
# 190       8   6.524860
# 478       6   5.432502
# 145       7   5.899000
#
# [343 rows x 2 columns]

# %%
import pickle

# %%
with open('linear.pkl', 'wb') as file:
    pickle.dump(model, file)
